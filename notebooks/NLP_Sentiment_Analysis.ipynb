# %%
import pandas as pd

# %%
reviews = pd.read_csv('../data/processed data/review_data.csv')

# %%
reviews.head()
# Out:
#     productID                      style      reviewerID reviewerName  \
# 0  B00009W3PA       {'Size:': ' 6-Foot'}  A1AHW6I678O6F2       kevin.
# 1  B0015UGPWQ  {'Size Name:': ' 4 Inch'}  A1AHW6I678O6F2       kevin.
# 2  B001769IVI                        NaN  A1AHW6I678O6F2       kevin.
# 3  B00009W3PA       {'Size:': ' 6-Foot'}   A8R48NKTGCJDQ    CDBrannom
# 4  B0015UGPWQ  {'Size Name:': ' 4 Inch'}   A8R48NKTGCJDQ    CDBrannom
#
#                        reviewText     summary  rating
# 0                       good item  Five Stars       5
# 1               very nice product  Five Stars       5
# 2              a must for washers  Five Stars       5
# 3  Fit my new LG dryer perfectly.  Five Stars       5
# 4                  Fits perfectly  Five Stars       5

# %%
reviews['reviewLen'] = reviews['reviewText'].str.split().map(lambda x: len(x))

# %%
reviews.shape
# Out:
# (166, 8)

# %% [markdown]
# <b> Since we have small amount of data, we will use all the review text data, larger length and smaller length review.</b>

# %% [markdown]
# <b> We will analyse the review texts using Sentiment analysis. We will be using 3 different NLP sentiment analysis packages:
#
#     * VADER : It uses a list of lexical features (e.g. word) which are labeled as positive or negative according to their   semantic orientation to calculate the text sentiment. Vader sentiment returns the probability of a given input sentence to be: Positive, negative, and neutral.
#
#     * TextBlob : Textblob sentiment analyzer returns two properties for a given input sentence:
#     Polarity is a float that lies between [-1,1], -1 indicates negative sentiment and +1 indicates positive sentiments.
#     Subjectivity is also a float which lies in the range of [0,1]. Subjective sentences generally refer to personal opinion, emotion, or judgment.
#
#     * Flair
# </b>

# %% [markdown]
# # Vader sentiment analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
def sentiment_analysis_scores(sentence):
    score = analyser.polarity_scores(sentence)
    return score

# %%
def sentiments_vader(reviews):

    reviews['text_sentiment'] = reviews['reviewText'].apply(sentiment_analysis_scores)

    reviews['compound'] = [x.get('compound') for x in reviews['text_sentiment']]
    reviews['neg'] = [x.get('neg') for x in reviews['text_sentiment']]
    reviews['neu'] = [x.get('neu') for x in reviews['text_sentiment']]
    reviews['pos'] = [x.get('pos') for x in reviews['text_sentiment']]
    
    return reviews

# %%
reviews_sent = sentiments_vader(reviews)

reviews_sent[reviews_sent['rating'] == 5].tail(10)
# Out:
#       productID style      reviewerID reviewerName  \
# 156  B00DM8J11Q   NaN   AFUVGAUNQVT0S     Brian M.
# 157  B00DM8KQ2Y   NaN   AFUVGAUNQVT0S     Brian M.
# 158  B00P9C66PM   NaN   AFUVGAUNQVT0S     Brian M.
# 159  B004XLDHSE   NaN  A2O7BWHBIV1HWZ     A/C dude
# 160  B00570RQ0A   NaN  A2O7BWHBIV1HWZ     A/C dude
# 161  B008YDSH6E   NaN  A2O7BWHBIV1HWZ     A/C dude
# 162  B00DM8J11Q   NaN  A2O7BWHBIV1HWZ     A/C dude
# 163  B00DM8JA7Q   NaN  A2O7BWHBIV1HWZ     A/C dude
# 164  B00JGTUQJ6   NaN   ALZOND1IEW8KS         Bill
# 165  B00JGTUQJ6   NaN   A2OP8DEIIUESP        Chris
#
#                                             reviewText  \
# 156  Common failure with the whilrlpool agitator af...
# 157  Common failure part on Whirlpool built top loa...
# 158  the spin clutch is a wear part on WP built top...
# 159                                     Worked great!!
# 160                                     worked great!!
# 161  Worked great!! I just wonder how long they las...
# 162                                            Great!!
# 163                                       worked great
# 164  Filter works just like the more expensive filters
# 165  First time I used this brand. But will buy it ...
#
#                                                summary  rating  reviewLen  \
# 156  Common failure with the whilrlpool agitator af...       5         23
# 157  This is an easy replacement and the customer w...       5         24
# 158  ... care of a slow spin issue and at a great p...       5         28
# 159                                         Five Stars       5          2
# 160                                         Five Stars       5          2
# 161    Worked great!! I just wonder how long they last       5         20
# 162                                         Five Stars       5          1
# 163                                         Five Stars       5          2
# 164                                        works great       5          8
# 165                                 water tastes great       5         23
#
#                                         text_sentiment  compound    neg  \
# 156  {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'comp...   -0.6908  0.213
# 157  {'neg': 0.182, 'neu': 0.662, 'pos': 0.156, 'co...   -0.2023  0.182
# 158  {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compou...    0.8964  0.000
# 159  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 160  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 161  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compou...    0.8577  0.000
# 162  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6892  0.000
# 163  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 164  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...    0.3612  0.000
# 165  {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'comp...    0.5023  0.000
#
#        neu    pos
# 156  0.787  0.000
# 157  0.662  0.156
# 158  0.670  0.330
# 159  0.176  0.824
# 160  0.176  0.824
# 161  0.680  0.320
# 162  0.000  1.000
# 163  0.196  0.804
# 164  0.737  0.263
# 165  0.871  0.129

# %% [markdown]
# # TextBlob sentiment analysis

# %%
# Creating lambda functions to find the polarity and subjectivity of each routine

from textblob import TextBlob

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity

reviews_sent['polarity'] = reviews_sent['reviewText'].apply(pol)
reviews_sent['subjectivity'] = reviews_sent['reviewText'].apply(sub)
reviews_sent[reviews_sent['rating'] == 5].tail(10)
# Out:
#       productID style      reviewerID reviewerName  \
# 156  B00DM8J11Q   NaN   AFUVGAUNQVT0S     Brian M.
# 157  B00DM8KQ2Y   NaN   AFUVGAUNQVT0S     Brian M.
# 158  B00P9C66PM   NaN   AFUVGAUNQVT0S     Brian M.
# 159  B004XLDHSE   NaN  A2O7BWHBIV1HWZ     A/C dude
# 160  B00570RQ0A   NaN  A2O7BWHBIV1HWZ     A/C dude
# 161  B008YDSH6E   NaN  A2O7BWHBIV1HWZ     A/C dude
# 162  B00DM8J11Q   NaN  A2O7BWHBIV1HWZ     A/C dude
# 163  B00DM8JA7Q   NaN  A2O7BWHBIV1HWZ     A/C dude
# 164  B00JGTUQJ6   NaN   ALZOND1IEW8KS         Bill
# 165  B00JGTUQJ6   NaN   A2OP8DEIIUESP        Chris
#
#                                             reviewText  \
# 156  Common failure with the whilrlpool agitator af...
# 157  Common failure part on Whirlpool built top loa...
# 158  the spin clutch is a wear part on WP built top...
# 159                                     Worked great!!
# 160                                     worked great!!
# 161  Worked great!! I just wonder how long they las...
# 162                                            Great!!
# 163                                       worked great
# 164  Filter works just like the more expensive filters
# 165  First time I used this brand. But will buy it ...
#
#                                                summary  rating  reviewLen  \
# 156  Common failure with the whilrlpool agitator af...       5         23
# 157  This is an easy replacement and the customer w...       5         24
# 158  ... care of a slow spin issue and at a great p...       5         28
# 159                                         Five Stars       5          2
# 160                                         Five Stars       5          2
# 161    Worked great!! I just wonder how long they last       5         20
# 162                                         Five Stars       5          1
# 163                                         Five Stars       5          2
# 164                                        works great       5          8
# 165                                 water tastes great       5         23
#
#                                         text_sentiment  compound    neg  \
# 156  {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'comp...   -0.6908  0.213
# 157  {'neg': 0.182, 'neu': 0.662, 'pos': 0.156, 'co...   -0.2023  0.182
# 158  {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compou...    0.8964  0.000
# 159  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 160  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 161  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compou...    0.8577  0.000
# 162  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6892  0.000
# 163  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 164  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...    0.3612  0.000
# 165  {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'comp...    0.5023  0.000
#
#        neu    pos  polarity  subjectivity
# 156  0.787  0.000 -0.272222      0.300000
# 157  0.662  0.156  0.079167      0.533333
# 158  0.670  0.330  0.333333      0.550000
# 159  0.176  0.824  1.000000      0.750000
# 160  0.176  0.824  1.000000      0.750000
# 161  0.680  0.320  0.457552      0.554167
# 162  0.000  1.000  1.000000      0.750000
# 163  0.196  0.804  0.800000      0.750000
# 164  0.737  0.263  0.000000      0.600000
# 165  0.871  0.129  0.000000      0.291667

# %% [markdown]
# # Flair sentiment analysis

# %%
from flair.models import TextClassifier
from flair.data import Sentence
import re

def isfloat(value):
  try:
    float(value)
    return True
  except ValueError:
    return False

classifier = TextClassifier.load('en-sentiment')
def flair_prediction(x):
    sentence = Sentence(x)
    classifier.predict(sentence)
    score = str(sentence.labels[0])
    score = score.replace('(',' ').replace(')',' ')
    number = [float(s) for s in score.split() if isfloat(s) is True]
    
    if "POSITIVE" in score:
        return number[0]
    elif "NEGATIVE" in score:
        return -number[0]
# Out:
# 2022-05-04 19:04:29,190 loading file C:\Users\varun\.flair\models\sentiment-en-mix-distillbert_4.pt

# %%
reviews_sent["flair_sentiment"] = reviews_sent["reviewText"].apply(flair_prediction)
reviews_sent.sample(20)
# Out:
#       productID                       style      reviewerID  \
# 13   B00CW0O1EW                         NaN  A2CIEGHZ7L1WWR
# 81   B000XXWOGW                         NaN  A1EUO0BU72JR7T
# 69   B000VL060M                         NaN  A34A1UP40713F8
# 15   B00P9C66PM                         NaN  A2CIEGHZ7L1WWR
# 132  B0056I99WG                         NaN   A6FPI5CM4W5WB
# 68   B000NCTOUM                         NaN  A34A1UP40713F8
# 78   B00DM8KQ2Y                         NaN  A26M3TN8QICJ3K
# 137  B00MGMWTQS                         NaN  A3H61AMBJ177DG
# 154  B008YDSH6E                         NaN   AFUVGAUNQVT0S
# 164  B00JGTUQJ6                         NaN   ALZOND1IEW8KS
# 133  B00MGMWTQS                         NaN   A6FPI5CM4W5WB
# 108  B00CW0O1EW                         NaN  A13391AZAFJ67K
# 142  B00MGMWTQS                         NaN   AVGG8CYK8K312
# 147  B0053F80JA                         NaN  A2V0JXLJ9VCNNX
# 100  B004UB1O9Q  {'Style Name:': ' 2 Pack'}  A1Y4UNHRP312HS
# 114  B00570RQ0A                         NaN  A37DQO5LU8DXTV
# 63   B000NCTOUM                         NaN  A1LN48DHHCKLR3
# 22   B0014CN8Y8                         NaN  A2LDP3A4IE9T6T
# 56   B008YDSH6E                         NaN  A1AJW9DILZFTQI
# 64   B000XXYUSM                         NaN  A1LN48DHHCKLR3
#
#           reviewerName                                         reviewText  \
# 13      albert j. kong  Price is good and it makes sense to have a few...
# 81               Bilbo  Consider the wisdom of spending a lot of money...
# 69       James. Backus  I bought a new range hood and found I needed a...
# 15      albert j. kong                  Price and delivery was excellent.
# 132         Tim Veteto                                           Good job
# 68       James. Backus  A spare thermofuse.  Two years ago my dryer sp...
# 78         Marty Baker                     Awesome, exactly what I needed
# 137       Randy Bailey                                      as advertised
# 154           Brian M.  These start devices are great for all domestic...
# 164               Bill  Filter works just like the more expensive filters
# 133         Tim Veteto                                              Great
# 108             Fred A                                            Exelent
# 142              Larry  Very satisfied I love these prices and prompt ...
# 147    Amazon Customer                                      WORKING GREAT
# 100     Colorado Jerry  This is the OEM filter. It removes contaminant...
# 114     Easy Appliance                                               good
# 63        Ernest Danel                                        received ok
# 22           mike27971  We have 24 foot of solid dryer vent pipe endin...
# 56   Riteway Appliance                      Great deal and fast shipping!
# 64        Ernest Danel                                        received ok
#
#                                                summary  rating  reviewLen  \
# 13                                          Five Stars       5         18
# 81   Works well as a replacement, if that's what yo...       5         83
# 69    I bought a new range hood and found I needed ...       5         49
# 15                                          Five Stars       5          5
# 132                                           Good job       5          2
# 68   A spare thermofuse. Two years ago my dryer spu...       4         40
# 78                                          Five Stars       5          5
# 137                                         Five Stars       5          2
# 154                      Got compressor start problem?       5         22
# 164                                        works great       5          8
# 133                                              Great       5          1
# 108                                         Five Stars       5          1
# 142                                         Five Stars       5         10
# 147                                         Five Stars       5          2
# 100                                      Does its Job.       5         54
# 114                                         Five Stars       5          1
# 63                                          Five Stars       5          2
# 22       This really worked well even taking shortcuts       5        371
# 56                                          Five Stars       5          5
# 64                                          Five Stars       5          2
#
#                                         text_sentiment  compound    neg  \
# 13   {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'comp...    0.8689  0.000
# 81   {'neg': 0.079, 'neu': 0.823, 'pos': 0.098, 'co...    0.1779  0.079
# 69   {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'comp...    0.8255  0.000
# 15   {'neg': 0.0, 'neu': 0.519, 'pos': 0.481, 'comp...    0.5719  0.000
# 132  {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...    0.4404  0.000
# 68   {'neg': 0.067, 'neu': 0.933, 'pos': 0.0, 'comp...   -0.4215  0.067
# 78   {'neg': 0.0, 'neu': 0.494, 'pos': 0.506, 'comp...    0.6249  0.000
# 137  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 154  {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'comp...    0.8622  0.000
# 164  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...    0.3612  0.000
# 133  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6249  0.000
# 108  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 142  {'neg': 0.0, 'neu': 0.392, 'pos': 0.608, 'comp...    0.8969  0.000
# 147  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 100  {'neg': 0.0, 'neu': 0.897, 'pos': 0.103, 'comp...    0.7178  0.000
# 114  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.4404  0.000
# 63   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960  0.000
# 22   {'neg': 0.035, 'neu': 0.885, 'pos': 0.08, 'com...    0.9483  0.035
# 56   {'neg': 0.0, 'neu': 0.477, 'pos': 0.523, 'comp...    0.6588  0.000
# 64   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960  0.000
#
#        neu    pos  polarity  subjectivity  flair_sentiment
# 13   0.605  0.395  0.500000      0.566667           0.9994
# 81   0.823  0.098  0.212500      0.456250         -10.0000
# 69   0.842  0.158  0.434545      0.561818           9.0000
# 15   0.519  0.481  1.000000      1.000000           0.9976
# 132  0.256  0.744  0.700000      0.600000           0.9976
# 68   0.933  0.000  0.000000      0.000000           0.9999
# 78   0.494  0.506  0.625000      0.625000           0.9981
# 137  1.000  0.000  0.000000      0.000000           0.9923
# 154  0.664  0.336  0.434583      0.650000           0.9995
# 164  0.737  0.263  0.000000      0.600000           0.9991
# 133  0.000  1.000  0.800000      0.750000           0.9901
# 108  1.000  0.000  0.000000      0.000000           0.9997
# 142  0.392  0.608  0.583333      0.866667           0.9894
# 147  0.196  0.804  0.800000      0.750000           0.9934
# 100  0.897  0.103  0.525000      0.850000           0.9993
# 114  0.000  1.000  0.700000      0.600000           0.9314
# 63   0.312  0.688  0.500000      0.500000          -0.5304
# 22   0.885  0.080  0.087121      0.514015          24.0000
# 56   0.477  0.523  0.525000      0.675000           0.9940
# 64   0.312  0.688  0.500000      0.500000          -0.5304

# %% [markdown]
# <b> It would be better to scale the flair sentiment scores, because there is a wide range.</b>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
reviews_sent['flair_scaled'] = scaler.fit_transform(reviews_sent[["flair_sentiment"]])
reviews_sent.sample(20)
# Out:
#       productID                      style      reviewerID       reviewerName  \
# 58   B004XLDDNI                        NaN  A11SCLK8GDDN3C         mrclobhead
# 1    B0015UGPWQ  {'Size Name:': ' 4 Inch'}  A1AHW6I678O6F2             kevin.
# 41   B000NCTOUM                        NaN  A3GP2HMB2AFOKF               Juan
# 0    B00009W3PA       {'Size:': ' 6-Foot'}  A1AHW6I678O6F2             kevin.
# 9    B0056I99WG                        NaN   AR3OHHHW01A8E    Calvin E Reames
# 31   B0006GVNOA                        NaN  A1WD61B0C3KQZB           Jason W.
# 108  B00CW0O1EW                        NaN  A13391AZAFJ67K             Fred A
# 146  B004XLDDNI                        NaN  A2V0JXLJ9VCNNX    Amazon Customer
# 153  B004XLDE5A                        NaN   AFUVGAUNQVT0S           Brian M.
# 160  B00570RQ0A                        NaN  A2O7BWHBIV1HWZ           A/C dude
# 115  B00CW0O1EW                        NaN  A37DQO5LU8DXTV     Easy Appliance
# 46   B00CW0O1EW                        NaN  A3GP2HMB2AFOKF               Juan
# 36   B0014CN8Y8                        NaN  A2B2JVUX5YN8RU              Caleb
# 52   B000NCTOUM                        NaN  A1AJW9DILZFTQI  Riteway Appliance
# 89   B00470A1S0                        NaN  A1HWFUO5PKB2RW        Greg bernal
# 66   B004XLDE5A                        NaN  A1LN48DHHCKLR3       Ernest Danel
# 154  B008YDSH6E                        NaN   AFUVGAUNQVT0S           Brian M.
# 111  B00470A1S0                        NaN  A37DQO5LU8DXTV     Easy Appliance
# 2    B001769IVI                        NaN  A1AHW6I678O6F2             kevin.
# 137  B00MGMWTQS                        NaN  A3H61AMBJ177DG       Randy Bailey
#
#                                             reviewText  \
# 58            All was fine, product was as advertised.
# 1                                    very nice product
# 41                                       Great product
# 0                                            good item
# 9                         Perfect fit for Maytag dryer
# 31   Great product but they need to include more ro...
# 108                                            Exelent
# 146                                        GREAT PART.
# 153  Common failure part in these dryers, but with ...
# 160                                     worked great!!
# 115                                               Good
# 46                                       Great product
# 36   Works great. I used it and an extension kit wi...
# 52                       Great deal and fast shipping!
# 89      it will last 6 mouths and u get to do it agian
# 66                                         received ok
# 154  These start devices are great for all domestic...
# 111  Sorry about that, I took too long to leave the...
# 2                                   a must for washers
# 137                                      as advertised
#
#                                                summary  rating  reviewLen  \
# 58                                          Five Stars       5          7
# 1                                           Five Stars       5          3
# 41                                          Five Stars       5          2
# 0                                           Five Stars       5          2
# 9                               Part was a perfect fit       5          5
# 31   Works Great, Just Use Common Sense When Doing ...       4        488
# 108                                         Five Stars       5          1
# 146                                         Five Stars       5          2
# 153  but with the great price on these replacements...       5         29
# 160                                         Five Stars       5          2
# 115                                         Five Stars       5          1
# 46                                          Five Stars       5          2
# 36                                 Worked like a charm       5        181
# 52                                          Five Stars       5          5
# 89                                            temp fix       2         12
# 66                                          Five Stars       5          2
# 154                      Got compressor start problem?       5         22
# 111    you are an amazing businessman. Thank you again       5         19
# 2                                           Five Stars       5          4
# 137                                         Five Stars       5          2
#
#                                         text_sentiment  compound    neg  \
# 58   {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'comp...    0.2023  0.000
# 1    {'neg': 0.0, 'neu': 0.393, 'pos': 0.607, 'comp...    0.4754  0.000
# 41   {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 0    {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...    0.4404  0.000
# 9    {'neg': 0.0, 'neu': 0.326, 'pos': 0.674, 'comp...    0.7351  0.000
# 31   {'neg': 0.064, 'neu': 0.823, 'pos': 0.113, 'co...    0.9807  0.064
# 108  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 146  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 153  {'neg': 0.061, 'neu': 0.769, 'pos': 0.169, 'co...    0.6996  0.061
# 160  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 115  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.4404  0.000
# 46   {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 36   {'neg': 0.028, 'neu': 0.83, 'pos': 0.142, 'com...    0.9591  0.028
# 52   {'neg': 0.0, 'neu': 0.477, 'pos': 0.523, 'comp...    0.6588  0.000
# 89   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 66   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960  0.000
# 154  {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'comp...    0.8622  0.000
# 111  {'neg': 0.105, 'neu': 0.63, 'pos': 0.265, 'com...    0.7003  0.105
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 137  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
#
#        neu    pos  polarity  subjectivity  flair_sentiment  flair_scaled
# 58   0.769  0.231  0.416667      0.500000           0.9949      0.038921
# 1    0.393  0.607  0.780000      1.000000           0.9863      0.038917
# 41   0.196  0.804  0.800000      0.750000           0.9886      0.038918
# 0    0.256  0.744  0.700000      0.600000           0.8820      0.038867
# 9    0.326  0.674  0.700000      0.700000           0.9999      0.038924
# 31   0.823  0.113  0.023000      0.470745         -60.0000      0.009611
# 108  1.000  0.000  0.000000      0.000000           0.9997      0.038923
# 146  0.196  0.804  0.800000      0.750000           0.9957      0.038922
# 153  0.769  0.169  0.156310      0.483810           0.9993      0.038923
# 160  0.176  0.824  1.000000      0.750000           0.9981      0.038923
# 115  0.000  1.000  0.700000      0.600000           0.9314      0.038891
# 46   0.196  0.804  0.800000      0.750000           0.9886      0.038918
# 36   0.830  0.142  0.154549      0.527764          21.0000      0.048534
# 52   0.477  0.523  0.525000      0.675000           0.9940      0.038921
# 89   1.000  0.000  0.000000      0.066667          -6.0000      0.035560
# 66   0.312  0.688  0.500000      0.500000          -0.5304      0.038188
# 154  0.664  0.336  0.434583      0.650000           0.9995      0.038923
# 111  0.630  0.265  0.016667      0.766667           0.8788      0.038865
# 2    1.000  0.000  0.000000      0.000000           0.9998      0.038923
# 137  1.000  0.000  0.000000      0.000000           0.9923      0.038920

# %%
review_transform = reviews_sent[['rating','flair_sentiment']]

# %%
from sklearn.preprocessing import PowerTransformer, QuantileTransformer
pt = PowerTransformer()

review_transform['flair_power'] = pt.fit_transform(X = review_transform[['flair_sentiment']])

review_transform
# Out:
# <ipython-input-15-11d8ccedaf08>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_transform['flair_power'] = pt.fit_transform(X = review_transform[['flair_sentiment']])
#      rating  flair_sentiment  flair_power
# 0         5           0.8820     0.055531
# 1         5           0.9863     0.057186
# 2         5           0.9998     0.057398
# 3         5           0.9998     0.057398
# 4         5           0.9975     0.057362
# ..      ...              ...          ...
# 161       5           0.9998     0.057398
# 162       5           0.9973     0.057359
# 163       5           0.9938     0.057304
# 164       5           0.9991     0.057387
# 165       5           0.9992     0.057388
#
# [166 rows x 3 columns]

# %%
qt = QuantileTransformer()

review_transform['flair_quantile'] = qt.fit_transform(X = review_transform[['flair_sentiment']])

review_transform
# Out:
# C:\Users\varun\anaconda3_2020_11\lib\site-packages\sklearn\preprocessing\_data.py:2367: UserWarning: n_quantiles (1000) is greater than the total number of samples (166). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# <ipython-input-16-0c00a5428513>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_transform['flair_quantile'] = qt.fit_transform(X = review_transform[['flair_sentiment']])
#      rating  flair_sentiment  flair_power  flair_quantile
# 0         5           0.8820     0.055531        0.206061
# 1         5           0.9863     0.057186        0.296970
# 2         5           0.9998     0.057398        0.836364
# 3         5           0.9998     0.057398        0.836364
# 4         5           0.9975     0.057362        0.557576
# ..      ...              ...          ...             ...
# 161       5           0.9998     0.057398        0.836364
# 162       5           0.9973     0.057359        0.551515
# 163       5           0.9938     0.057304        0.454545
# 164       5           0.9991     0.057387        0.693939
# 165       5           0.9992     0.057388        0.712121
#
# [166 rows x 4 columns]

# %%
qt = QuantileTransformer(output_distribution = 'normal')

review_transform['flair_quantile_normal'] = qt.fit_transform(X = review_transform[['flair_sentiment']])

review_transform
# Out:
# C:\Users\varun\anaconda3_2020_11\lib\site-packages\sklearn\preprocessing\_data.py:2367: UserWarning: n_quantiles (1000) is greater than the total number of samples (166). n_quantiles is set to n_samples.
#   warnings.warn("n_quantiles (%s) is greater than the total number "
# <ipython-input-17-7c1abe4ebd56>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   review_transform['flair_quantile_normal'] = qt.fit_transform(X = review_transform[['flair_sentiment']])
#      rating  flair_sentiment  flair_power  flair_quantile  \
# 0         5           0.8820     0.055531        0.206061
# 1         5           0.9863     0.057186        0.296970
# 2         5           0.9998     0.057398        0.836364
# 3         5           0.9998     0.057398        0.836364
# 4         5           0.9975     0.057362        0.557576
# ..      ...              ...          ...             ...
# 161       5           0.9998     0.057398        0.836364
# 162       5           0.9973     0.057359        0.551515
# 163       5           0.9938     0.057304        0.454545
# 164       5           0.9991     0.057387        0.693939
# 165       5           0.9992     0.057388        0.712121
#
#      flair_quantile_normal
# 0                -0.820166
# 1                -0.533136
# 2                 0.979622
# 3                 0.979622
# 4                 0.144826
# ..                     ...
# 161               0.979622
# 162               0.129490
# 163              -0.114185
# 164               0.507048
# 165               0.559592
#
# [166 rows x 5 columns]

# %%
reviews_sent.tail(40)
# Out:
#       productID                  style      reviewerID          reviewerName  \
# 126  B00P9C66PM                    NaN  A23KSPVPHZF6EO  Angela Samos Guardia
# 127  B001DPFP88                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 128  B00470A1S0                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 129  B004XLDDNI                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 130  B004XLDE5A                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 131  B0053F80JA                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 132  B0056I99WG                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 133  B00MGMWTQS                    NaN   A6FPI5CM4W5WB            Tim Veteto
# 134  B001DPFP88                    NaN  A3H61AMBJ177DG          Randy Bailey
# 135  B00470A1S0                    NaN  A3H61AMBJ177DG          Randy Bailey
# 136  B00DM8KQ2Y                    NaN  A3H61AMBJ177DG          Randy Bailey
# 137  B00MGMWTQS                    NaN  A3H61AMBJ177DG          Randy Bailey
# 138  B00W4YKCGC                    NaN  A3H61AMBJ177DG          Randy Bailey
# 139  B001DPFP88                    NaN   AVGG8CYK8K312                 Larry
# 140  B00CW0O1EW                    NaN   AVGG8CYK8K312                 Larry
# 141  B00DM8JA7Q                    NaN   AVGG8CYK8K312                 Larry
# 142  B00MGMWTQS                    NaN   AVGG8CYK8K312                 Larry
# 143  B00W4YKCGC                    NaN   AVGG8CYK8K312                 Larry
# 144  B004UB1O9Q  {'Style:': ' 3 Pack'}  A329823SXZ8IBE                    J!
# 145  B00AHR3IG4                    NaN  A329823SXZ8IBE                    J!
# 146  B004XLDDNI                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 147  B0053F80JA                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 148  B0056I99WG                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 149  B00570RQ0A                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 150  B00DM8J11Q                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 151  B00MGMWTQS                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 152  B00P9C66PM                    NaN  A2V0JXLJ9VCNNX       Amazon Customer
# 153  B004XLDE5A                    NaN   AFUVGAUNQVT0S              Brian M.
# 154  B008YDSH6E                    NaN   AFUVGAUNQVT0S              Brian M.
# 155  B00CW0O1EW                    NaN   AFUVGAUNQVT0S              Brian M.
# 156  B00DM8J11Q                    NaN   AFUVGAUNQVT0S              Brian M.
# 157  B00DM8KQ2Y                    NaN   AFUVGAUNQVT0S              Brian M.
# 158  B00P9C66PM                    NaN   AFUVGAUNQVT0S              Brian M.
# 159  B004XLDHSE                    NaN  A2O7BWHBIV1HWZ              A/C dude
# 160  B00570RQ0A                    NaN  A2O7BWHBIV1HWZ              A/C dude
# 161  B008YDSH6E                    NaN  A2O7BWHBIV1HWZ              A/C dude
# 162  B00DM8J11Q                    NaN  A2O7BWHBIV1HWZ              A/C dude
# 163  B00DM8JA7Q                    NaN  A2O7BWHBIV1HWZ              A/C dude
# 164  B00JGTUQJ6                    NaN   ALZOND1IEW8KS                  Bill
# 165  B00JGTUQJ6                    NaN   A2OP8DEIIUESP                 Chris
#
#                                             reviewText  \
# 126  This works great, wonderful product it worked ...
# 127                                          Good  Job
# 128                            Great product, on time.
# 129                                              Great
# 130                                              Great
# 131                                              Great
# 132                                           Good job
# 133                                              Great
# 134                                      as advertised
# 135                                      as advertised
# 136                                      as advertised
# 137                                      as advertised
# 138                                     as advertised.
# 139                    great price I keep one in stock
# 140                very low price good money maker too
# 141  These are a great buy I replace alot of them t...
# 142  Very satisfied I love these prices and prompt ...
# 143  I use these regular on my jobs I love the pric...
# 144  Fit perfectly in my fridge.  No leaks and the ...
# 145  Fit perfectly in my fridge.  No leaks and the ...
# 146                                        GREAT PART.
# 147                                      WORKING GREAT
# 148                                DRYER WORKING GREAT
# 149                                     washer washing
# 150                                         GOOD DOGS.
# 151                                      JUST RIGHT...
# 152                               WASHER SPINNING NOW.
# 153  Common failure part in these dryers, but with ...
# 154  These start devices are great for all domestic...
# 155  This muti pack makes sure I always have the pa...
# 156  Common failure with the whilrlpool agitator af...
# 157  Common failure part on Whirlpool built top loa...
# 158  the spin clutch is a wear part on WP built top...
# 159                                     Worked great!!
# 160                                     worked great!!
# 161  Worked great!! I just wonder how long they las...
# 162                                            Great!!
# 163                                       worked great
# 164  Filter works just like the more expensive filters
# 165  First time I used this brand. But will buy it ...
#
#                                                summary  rating  reviewLen  \
# 126                                         Five Stars       5          8
# 127                                          Good  Job       5          2
# 128                                              Great       5          4
# 129                                              Great       5          1
# 130                                              Great       5          1
# 131                                              Great       5          1
# 132                                           Good job       5          2
# 133                                              Great       5          1
# 134                                         Five Stars       5          2
# 135                                         Five Stars       5          2
# 136                                         Five Stars       5          2
# 137                                         Five Stars       5          2
# 138                                         Five Stars       5          2
# 139                                      Washer clutch       5          7
# 140                                      Thermal fuses       5          7
# 141                                         Lid switch       5         15
# 142                                         Five Stars       5         10
# 143                                         Five Stars       5         12
# 144                                            Awesome       5         12
# 145                                            Awesome       5         12
# 146                                         Five Stars       5          2
# 147                                         Five Stars       5          2
# 148                                         Five Stars       5          3
# 149                                         Five Stars       5          2
# 150                                         Five Stars       5          2
# 151                                         Five Stars       5          2
# 152                                         Five Stars       5          3
# 153  but with the great price on these replacements...       5         29
# 154                      Got compressor start problem?       5         22
# 155  This muti pack makes sure I always have the pa...       5         25
# 156  Common failure with the whilrlpool agitator af...       5         23
# 157  This is an easy replacement and the customer w...       5         24
# 158  ... care of a slow spin issue and at a great p...       5         28
# 159                                         Five Stars       5          2
# 160                                         Five Stars       5          2
# 161    Worked great!! I just wonder how long they last       5         20
# 162                                         Five Stars       5          1
# 163                                         Five Stars       5          2
# 164                                        works great       5          8
# 165                                 water tastes great       5         23
#
#                                         text_sentiment  compound    neg  \
# 126  {'neg': 0.0, 'neu': 0.318, 'pos': 0.682, 'comp...    0.8934  0.000
# 127  {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...    0.4404  0.000
# 128  {'neg': 0.0, 'neu': 0.423, 'pos': 0.577, 'comp...    0.6249  0.000
# 129  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6249  0.000
# 130  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6249  0.000
# 131  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6249  0.000
# 132  {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...    0.4404  0.000
# 133  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6249  0.000
# 134  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 135  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 136  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 137  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 138  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 139  {'neg': 0.0, 'neu': 0.594, 'pos': 0.406, 'comp...    0.6249  0.000
# 140  {'neg': 0.227, 'neu': 0.474, 'pos': 0.3, 'comp...    0.1952  0.227
# 141  {'neg': 0.0, 'neu': 0.588, 'pos': 0.412, 'comp...    0.8126  0.000
# 142  {'neg': 0.0, 'neu': 0.392, 'pos': 0.608, 'comp...    0.8969  0.000
# 143  {'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'comp...    0.6369  0.000
# 144  {'neg': 0.105, 'neu': 0.381, 'pos': 0.514, 'co...    0.8625  0.105
# 145  {'neg': 0.105, 'neu': 0.381, 'pos': 0.514, 'co...    0.8625  0.105
# 146  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 147  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 148  {'neg': 0.0, 'neu': 0.328, 'pos': 0.672, 'comp...    0.6249  0.000
# 149  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 150  {'neg': 0.0, 'neu': 0.256, 'pos': 0.744, 'comp...    0.4404  0.000
# 151  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 152  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000  0.000
# 153  {'neg': 0.061, 'neu': 0.769, 'pos': 0.169, 'co...    0.6996  0.061
# 154  {'neg': 0.0, 'neu': 0.664, 'pos': 0.336, 'comp...    0.8622  0.000
# 155  {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'comp...    0.6705  0.000
# 156  {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'comp...   -0.6908  0.213
# 157  {'neg': 0.182, 'neu': 0.662, 'pos': 0.156, 'co...   -0.2023  0.182
# 158  {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compou...    0.8964  0.000
# 159  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 160  {'neg': 0.0, 'neu': 0.176, 'pos': 0.824, 'comp...    0.6892  0.000
# 161  {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compou...    0.8577  0.000
# 162  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.6892  0.000
# 163  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...    0.6249  0.000
# 164  {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'comp...    0.3612  0.000
# 165  {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'comp...    0.5023  0.000
#
#        neu    pos  polarity  subjectivity  flair_sentiment  flair_scaled
# 126  0.318  0.682  0.833333      0.783333           0.9897      0.038919
# 127  0.256  0.744  0.700000      0.600000           0.9976      0.038922
# 128  0.423  0.577  0.800000      0.750000           0.9855      0.038917
# 129  0.000  1.000  0.800000      0.750000           0.9901      0.038919
# 130  0.000  1.000  0.800000      0.750000           0.9901      0.038919
# 131  0.000  1.000  0.800000      0.750000           0.9901      0.038919
# 132  0.256  0.744  0.700000      0.600000           0.9976      0.038922
# 133  0.000  1.000  0.800000      0.750000           0.9901      0.038919
# 134  1.000  0.000  0.000000      0.000000           0.9923      0.038920
# 135  1.000  0.000  0.000000      0.000000           0.9923      0.038920
# 136  1.000  0.000  0.000000      0.000000           0.9923      0.038920
# 137  1.000  0.000  0.000000      0.000000           0.9923      0.038920
# 138  1.000  0.000  0.000000      0.000000           0.9949      0.038921
# 139  0.594  0.406  0.800000      0.750000           0.9980      0.038923
# 140  0.474  0.300  0.350000      0.495000           0.9949      0.038921
# 141  0.588  0.412  0.538889      0.550000           0.9984      0.038923
# 142  0.392  0.608  0.583333      0.866667           0.9894      0.038919
# 143  0.724  0.276  0.250000      0.338462           0.9866      0.038917
# 144  0.381  0.514  0.733333      0.716667           0.9997      0.038923
# 145  0.381  0.514  0.733333      0.716667           0.9997      0.038923
# 146  0.196  0.804  0.800000      0.750000           0.9957      0.038922
# 147  0.196  0.804  0.800000      0.750000           0.9934      0.038920
# 148  0.328  0.672  0.800000      0.750000           0.9955      0.038921
# 149  1.000  0.000  0.000000      0.000000           0.9559      0.038902
# 150  0.256  0.744  0.700000      0.600000           0.9978      0.038923
# 151  1.000  0.000  0.285714      0.535714           0.9988      0.038923
# 152  1.000  0.000  0.000000      0.000000           0.9835      0.038916
# 153  0.769  0.169  0.156310      0.483810           0.9993      0.038923
# 154  0.664  0.336  0.434583      0.650000           0.9995      0.038923
# 155  0.807  0.193  0.500000      0.888889           0.9995      0.038923
# 156  0.787  0.000 -0.272222      0.300000          -0.9999      0.037963
# 157  0.662  0.156  0.079167      0.533333          -0.9225      0.038000
# 158  0.670  0.330  0.333333      0.550000           0.9994      0.038923
# 159  0.176  0.824  1.000000      0.750000           0.9981      0.038923
# 160  0.176  0.824  1.000000      0.750000           0.9981      0.038923
# 161  0.680  0.320  0.457552      0.554167           0.9998      0.038923
# 162  0.000  1.000  1.000000      0.750000           0.9973      0.038922
# 163  0.196  0.804  0.800000      0.750000           0.9938      0.038921
# 164  0.737  0.263  0.000000      0.600000           0.9991      0.038923
# 165  0.871  0.129  0.000000      0.291667           0.9992      0.038923

# %%
reviews_sent['rating'].describe()
# Out:
# count    166.000000
# mean       4.620482
# std        0.956922
# min        1.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# Name: rating, dtype: float64

# %%
# compound if > 0 its a positive sentiment else negative
reviews_sent['compound'].describe()
# Out:
# count    166.000000
# mean       0.514346
# std        0.354421
# min       -0.948100
# 25%        0.296000
# 50%        0.624900
# 75%        0.761400
# max        0.993500
# Name: compound, dtype: float64

# %%
# polarity if > 0 its a positive sentiment else negative
reviews_sent['polarity'].describe()
# Out:
# count    166.000000
# mean       0.441175
# std        0.323945
# min       -0.272222
# 25%        0.154989
# 50%        0.500000
# 75%        0.700000
# max        1.000000
# Name: polarity, dtype: float64

# %%
review_transform[['flair_sentiment','flair_power','flair_quantile']].describe()
# Out:
#        flair_sentiment   flair_power  flair_quantile
# count       166.000000  1.660000e+02      166.000000
# mean         37.435637 -8.401914e-17        0.500146
# std         267.324035  1.003026e+00        0.291215
# min         -80.000000 -5.085470e+00        0.000000
# 25%           0.931400  5.631851e-02        0.242424
# 50%           0.994900  5.732098e-02        0.496970
# 75%           0.999400  5.739162e-02        0.748485
# max        2001.000000  4.784332e+00        1.000000

# %%
# range between 0 to 1 for scaled
reviews_sent['flair_scaled'].describe()
# Out:
# count    166.000000
# mean       0.056432
# std        0.128459
# min        0.000000
# 25%        0.038891
# 50%        0.038921
# 75%        0.038923
# max        1.000000
# Name: flair_scaled, dtype: float64

# %% [markdown]
# <b> The Vader and TextBlob sentiment analysis looks pretty decent compared to flair sentiment analysis. The range of sentiment score for flair is large. The former 2 packages looks more promising.</b>

# %%
import scattertext as st

# %%
reviews_sent['Liked'] = reviews_sent.rating.apply(lambda x: x > 3).map({True: 'Liked', False: 'Not Liked'})

reviews_sent['Liked']
# Out:
# 0      Liked
# 1      Liked
# 2      Liked
# 3      Liked
# 4      Liked
#        ...
# 161    Liked
# 162    Liked
# 163    Liked
# 164    Liked
# 165    Liked
# Name: Liked, Length: 166, dtype: object

# %%
corpus = st.CorpusFromPandas(
    reviews_sent,
    category_col = 'Liked',
    text_col = 'reviewText',
    nlp=st.whitespace_nlp_with_sentences
).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category="Liked",
        category_name='Liked',
        not_category_name='Not Liked',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=reviews_sent['productID']
        )

# %%
open('reviews_scatter.html', 'wb').write(html.encode('utf-8'));

# %%
reviews_sent['Liked'] = reviews_sent.polarity.apply(lambda x: x > 0).map({True: 'Liked', False: 'Not Liked'})

reviews_sent['Liked']
# Out:
# 0          Liked
# 1          Liked
# 2      Not Liked
# 3          Liked
# 4          Liked
#          ...
# 161        Liked
# 162        Liked
# 163        Liked
# 164    Not Liked
# 165    Not Liked
# Name: Liked, Length: 166, dtype: object

# %%
corpus = st.CorpusFromPandas(
    reviews_sent,
    category_col = 'Liked',
    text_col = 'reviewText',
    nlp=st.whitespace_nlp_with_sentences
).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category="Liked",
        category_name='Liked',
        not_category_name='Not Liked',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=reviews_sent['productID']
        )

# %%
open('reviews_scatter_textblob.html', 'wb').write(html.encode('utf-8'));

# %%
reviews_sent['Liked'] = reviews_sent.compound.apply(lambda x: x > 0).map({True: 'Liked', False: 'Not Liked'})

reviews_sent['Liked']
# Out:
# 0          Liked
# 1          Liked
# 2      Not Liked
# 3          Liked
# 4          Liked
#          ...
# 161        Liked
# 162        Liked
# 163        Liked
# 164        Liked
# 165        Liked
# Name: Liked, Length: 166, dtype: object

# %%
corpus = st.CorpusFromPandas(
    reviews_sent,
    category_col = 'Liked',
    text_col = 'reviewText',
    nlp=st.whitespace_nlp_with_sentences
).build()

# %%
html = st.produce_scattertext_explorer(
        corpus,
        category="Liked",
        category_name='Liked',
        not_category_name='Not Liked',
        minimum_term_frequency=10,
        pmi_threshold_coefficient=5,
        width_in_pixels=1000,
        metadata=reviews_sent['productID']
        )

# %%
open('reviews_scatter_vader.html', 'wb').write(html.encode('utf-8'));

# %%
reviews_final = reviews_sent[['productID','reviewerID','reviewerName','rating','Liked']]

# %%
liked_5 = reviews_final.query('rating == 5')

# %%
liked_5.Liked.value_counts(normalize=True)
# Out:
# Liked        0.870504
# Not Liked    0.129496
# Name: Liked, dtype: float64
